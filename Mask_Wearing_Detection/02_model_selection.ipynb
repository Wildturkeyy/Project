# %%
import pandas as pd 
import numpy as np

# %%
result = pd.read_csv('./benchmark/benchmark.csv', index_col=0)
result.sort_values('val_accuracy', ascending=False)
# Out:
#            model_name  num_model_params  val_loss  val_accuracy  \
# 21         ResNet50V2          23564800  0.507737         0.804
# 17        ResNet101V2          42626560  0.552242         0.787
# 19        ResNet152V2          58331648  0.557212         0.785
# 7         DenseNet201          18321984  0.543476         0.779
# 10          MobileNet           3228864  0.562246         0.766
# 6         DenseNet169          12642880  0.553882         0.763
# 31           Xception          20861480  0.583406         0.759
# 8   InceptionResNetV2          54336736  0.615877         0.751
# 14        NASNetLarge          84916818  0.622449         0.730
# 5         DenseNet121           7037504  0.670138         0.715
# 11        MobileNetV2           2257984  0.683765         0.708
# 9         InceptionV3          21802784  0.701376         0.683
# 15       NASNetMobile           4269716  0.746961         0.671
# 0        ConvNeXtBase          87566464  1.002202         0.584
# ...
